# %%
import numpy as np



OPTIC_STATUS = {
    "Busy": { "id": 0, "desc": "The optic controller executes a feature access/command." },
    "Error": { "id": 0, "desc": "The optic controller encountered an error." },
    "NotConnected": { "id": 0, "desc": "The optic contoller is physically not connected." },
    "NotInitialized": { "id": 0, "desc": "The optic controller is not initialized." },
    "NotSupported": { "id": 0, "desc": "The optic controller is physically connected but not supported." },
    "Ready": { "id": 0, "desc": "The optic controller is ready to use."  }
}
