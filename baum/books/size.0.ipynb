# %%
from pathlib import Path


def size(folder, prefix, extension):
    return sum(file.stat().st_size for file in Path(folder).rglob(''.join([prefix,'*.',extension])))
    
folder = r"C:\Develop\py\FluidicsLab\Drafts\baum\data"
size(folder,'none','jpg')
# Out:
# 34378378
