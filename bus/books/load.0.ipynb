# %%
import psutil
import time

psutil.cpu_count(), psutil.cpu_percent(interval=None), psutil.cpu_percent(interval=None, percpu=True)
# Out:
# (16,
#  1.5,
#  [0.6,
#   1.2,
#   3.8,
#   0.4,
#   3.3,
#   0.8,
#   0.5,
#   1.5,
#   0.2,
#   1.4,
#   1.0,
#   1.2,
#   2.2,
#   0.7,
#   0.7,
#   0.7])
