# %%
_limit = {
    'output': { "low": -24_185_993*8/9, "high": 24_185_993*8/9 }  # inc/s (velocity)
}

def limit(value): 
    return max(_limit['output']['low'], min(_limit['output']['high'], value))

limit(73264796)
# Out:
# 21498660.444444444

# %%
import time 

t = time.time_ns()

time.sleep(0.1)

(time.time_ns() - t) / 10 ** 9
# Out:
# 0.1002628
